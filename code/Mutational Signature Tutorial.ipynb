# %%
from Positional_Mutational_Signature import Positional_Mutational_Signature

# %%
for subject_id in range(1, 3):
    print('Computing PMS for subject %d...' % subject_id)
    pms = Positional_Mutational_Signature(subject_file_path = '../Texas_vcfs/wheeljack' + str(subject_id) + '.vcf')
    pms.visualize_ms_burden(1)
    pms.visualize_ms_plot(pms.overall_mutational_signature, 'subj_' + str(subject_id) + '_overall')
    for chrom_idx in pms.pms_dict:
        for interval in pms.pms_dict[chrom_idx]:
            sub_title = 'subj_%d_chr_%d_from_%d_to_%d' % (subject_id, chrom_idx, interval[0], interval[1])
            pms.visualize_ms_plot(pms.pms_dict[chrom_idx][interval], sub_title)
    print('bad_reads', pms.bad_records)
# Out:
# Computing PMS for subject 1...
# [PROGRESS] processing Chromosome #1
# [PROGRESS] processing Chromosome #2
# [PROGRESS] processing Chromosome #3
# [PROGRESS] processing Chromosome #4
# [PROGRESS] processing Chromosome #5
# [PROGRESS] processing Chromosome #6
# [PROGRESS] processing Chromosome #7
# [PROGRESS] processing Chromosome #8
# [PROGRESS] processing Chromosome #9
# [PROGRESS] processing Chromosome #10
# [PROGRESS] processing Chromosome #11
# [PROGRESS] processing Chromosome #12
# [PROGRESS] processing Chromosome #13
# [PROGRESS] processing Chromosome #14
# [PROGRESS] processing Chromosome #15
# [PROGRESS] processing Chromosome #16
# [PROGRESS] processing Chromosome #17
# [PROGRESS] processing Chromosome #18
# [PROGRESS] processing Chromosome #19
# [PROGRESS] processing Chromosome #20
# [PROGRESS] processing Chromosome #21
# [PROGRESS] processing Chromosome #22
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7e8f9b0831bc> in <module>()
#       8             sub_title = 'subj_%d_chr_%d_from_%d_to_%d' % (subject_id, chrom_idx, interval[0], interval[1])
#       9             pms.visualize_ms_plot(pms.pms_dict[chrom_idx][interval], sub_title)
# ---> 10     print('bad_reads', pms_1.bad_records)
#
# NameError: name 'pms_1' is not defined

# %%
# define parameters
subject_id = 1
chrom_idx = 6
interval = (29000001, 30000000)
# create pms for subject 1 
pms = Positional_Mutational_Signature(subject_file_path = '../Texas_vcfs/wheeljack' + str(subject_id) + '.vcf')
# visualize pms burden
pms.visualize_ms_burden(1)
# viaualize subject1's pms for window from pos 29000001 to 30000000 in chr6
sub_title = 'subj_%d_chr_%d_from_%d_to_%d' % (subject_id, chrom_idx, interval[0], interval[1])
pms.visualize_ms_plot(pms.pms_dict[chrom_idx][interval], sub_title)
# Out:
# [PROGRESS] processing Chromosome #1
# [PROGRESS] processing Chromosome #2
# [PROGRESS] processing Chromosome #3
# [PROGRESS] processing Chromosome #4
# [PROGRESS] processing Chromosome #5
# [PROGRESS] processing Chromosome #6
# [PROGRESS] processing Chromosome #7
# [PROGRESS] processing Chromosome #8
# [PROGRESS] processing Chromosome #9
# [PROGRESS] processing Chromosome #10
# [PROGRESS] processing Chromosome #11
# [PROGRESS] processing Chromosome #12
# [PROGRESS] processing Chromosome #13
# [PROGRESS] processing Chromosome #14
# [PROGRESS] processing Chromosome #15
# [PROGRESS] processing Chromosome #16
# [PROGRESS] processing Chromosome #17
# [PROGRESS] processing Chromosome #18
# [PROGRESS] processing Chromosome #19
# [PROGRESS] processing Chromosome #20
# [PROGRESS] processing Chromosome #21
# [PROGRESS] processing Chromosome #22
